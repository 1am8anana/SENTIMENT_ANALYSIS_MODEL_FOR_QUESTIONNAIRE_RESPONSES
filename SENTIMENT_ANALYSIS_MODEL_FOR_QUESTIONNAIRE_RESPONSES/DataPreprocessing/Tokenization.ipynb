# %% [markdown]
# # Tokenization

# %% [markdown]
# ##### Import library

# %% [markdown]
# import pandas library to handle dataframe, Tokenizer for make the sentence to tokens.

# %%
import pandas as pd
from CustomTokenizer import Tokenizer

# %% [markdown]
# ##### Load the dataset

# %%
datasets = pd.read_csv('../Dataset/datasets.csv')
# Get the sentences
sentences = datasets['sentence']

# %% [markdown]
# ##### Tokenize the sentence

# %%
# Instantiate the Tokenizer.
tokenizer = Tokenizer()
# Fit the sentences and transforms it to the tokesn.
str_tokens = tokenizer.fit_transform(sentences)

# %% [markdown]
# #### The result of Tokenization

# %%
str_tokens
# Out:
# ['กล้า ป่าว ระบบ การศึกษา มันดี อ่ะ ถุ้ย เฟส ปลอม สัส',
#  'เบื่อ เวลา โพ สต แบบนี้ ชอบ โปรไฟล์ โปรไฟล์ ตัวเอง เสือก ลึก แบบนี้ จุ',
#  'พ่อ ติ่ง รัฐบาล หรอ สัส ตัง แพง แดก อะ ควย',
#  'ลบ ไอ้ ออกจาก โพสต์ เกรียน กวน ส้นตีน แน่จริง กล้า เฟส โพสต์ ไหม',
#  'เครียด อะ ตอนนี้',
#  'กำลังใจ สู้',
#  'ท้อ ไหว 😭😭',
#  'เรียน เหมือน เครียด หนัก 😭😭😭 คน เรียน',
#  'หดหู่ ทีม เรียน',
#  'เศร้า สอบ มีโอกาส แก้ตัว รอบ ต้องโทษ ตัวเอง ทำ ออกมา ดี',
#  'เสียกำลังใจ',
#  'พี่ กำลังใจ สู้',
#  'ดีใจ',
#  'ชีวิต สำเร็จ ความพยายาม เข้มแข็ง เดินทาง ก้อ เกิดขึ้น สู้ นะคะ',
#  'ขอบคุณ กำลังใจ นะคะ ทำ ดี',
#  'สู้',
#  'สู้ ยังมี หนทาง ผม กำลังใจ',
#  'สู้ กะ อี อย่า ท้อ เดิน ข้างหน้า ต่อไป',
#  'เรียน รัก ชอบ ทำ ได้ดี มีความสุข',
#  'สู้ ชีวิต การต่อสู้ 😊✌',
#  'เว็บ ล่ม ล่ม เหมือน อนาคต',
#  'หัว ร้อน ตอนนี้',
#  'เย สเเม่ ไอ้ เปรต ต่อย ที่มา หัว ดอ เเร้วเ เละ เห งัน',
#  'ตรรกะ ป่วย ป่ะ',
#  'ระบบ เน่า ทปอ สักที เห้อ',
#  'เรื่อง ดีใจ สอบ ติด ค้นพบ ตัวเอง',
# ...

# %% [markdown]
# This result means that each sentence will split into the tokens and each tokens will have some meaningfull for classifier.
